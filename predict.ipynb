# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('data.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]>

# %%
df.shape
# Out:
# (569, 33)

# %%
sns.pairplot(df,hue='diagnosis',palette='coolwarm',vars=['radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean'])

# %%
df.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
df=df.dropna(axis=1)

# %%
df.shape
# Out:
# (569, 32)

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
sns.countplot(df['diagnosis'], label = 'count')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\ASUS\Desktop\PROGRAMMING\Breast Cancer prediction\predict.ipynb Cell 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Desktop/PROGRAMMING/Breast%20Cancer%20prediction/predict.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> sns.countplot(df['diagnosis'], label = 'count')
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:2939, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2936 elif x is not None and y is not None:
#    2937     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2939 plotter = _CountPlotter(
#    2940     x, y, hue, data, order, hue_order,
#    2941     estimator, errorbar, n_boot, units, seed,
#    2942     orient, color, palette, saturation,
#    2943     width, errcolor, errwidth, capsize, dodge
#    2944 )
#    2946 plotter.value_label = "count"
#    2948 if ax is None:
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:1530, in _BarPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1525 def __init__(self, x, y, hue, data, order, hue_order,
#    1526              estimator, errorbar, n_boot, units, seed,
#    1527              orient, color, palette, saturation, width,
#    1528              errcolor, errwidth, capsize, dodge):
#    1529     """Initialize the plotter."""
# -> 1530     self.establish_variables(x, y, hue, data, orient,
#    1531                              order, hue_order, units)
#    1532     self.establish_colors(color, palette, saturation)
#    1533     self.estimate_statistic(estimator, errorbar, n_boot, seed)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:516, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     513     plot_data = data
#     515 # Convert to a list of arrays, the common representation
# --> 516 plot_data = [np.asarray(d, float) for d in plot_data]
#     518 # The group names will just be numeric indices
#     519 group_names = list(range(len(plot_data)))
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:516, in <listcomp>(.0)
#     513     plot_data = data
#     515 # Convert to a list of arrays, the common representation
# --> 516 plot_data = [np.asarray(d, float) for d in plot_data]
#     518 # The group names will just be numeric indices
#     519 group_names = list(range(len(plot_data)))
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:894, in Series.__array__(self, dtype)
#     847 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#     848     """
#     849     Return the values as a NumPy array.
#     850
#    (...)
#     892           dtype='datetime64[ns]')
#     893     """
# --> 894     return np.asarray(self._values, dtype)
#
# ValueError: could not convert string to float: 'M'

# %%
df.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# concavity_worst            float64
# concave points_worst       float64
# symmetry_worst             float64
# fractal_dimension_worst    float64
# dtype: object

# %%
df=df.rename(columns={'diagnosis':'label'})

# %%
print(df.dtypes)
# Out:
# id                           int64
# label                       object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# concavity_worst            float64
# concave points_worst       float64
# symmetry_worst             float64
# fractal_dimension_worst    float64
# dtype: object

# %%
y=df['label'].values

# %%
print(np.unique(y))
# Out:
# ['B' 'M']

# %%
#convert them to 1 or 0

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()
Y=lab.fit_transform(y)

# %%
print(np.unique(Y))
# Out:
# [0 1]

# %%
X=df.drop(labels=['label','id'],axis=1)

# %%
print(X)
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 0                   0.07871  ...        25.380          17.33
# 1                   0.05667  ...        24.990          23.41
# 2                   0.05999  ...        23.570          25.53
# 3                   0.09744  ...        14.910          26.50
# 4                   0.05883  ...        22.540          16.67
# ..                      ...  ...           ...            ...
# 564                 0.05623  ...        25.450          26.40
# 565                 0.05533  ...        23.690          38.25
# 566                 0.05648  ...        18.980          34.12
# 567                 0.07016  ...        25.740          39.42
# 568                 0.05884  ...         9.456          30.37
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0             184.60      2019.0           0.16220            0.66560
# 1             158.80      1956.0           0.12380            0.18660
# 2             152.50      1709.0           0.14440            0.42450
# 3              98.87       567.7           0.20980            0.86630
# 4             152.20      1575.0           0.13740            0.20500
# ..               ...         ...               ...                ...
# 564           166.10      2027.0           0.14100            0.21130
# 565           155.00      1731.0           0.11660            0.19220
# 566           126.70      1124.0           0.11390            0.30940
# 567           184.60      1821.0           0.16500            0.86810
# 568            59.16       268.6           0.08996            0.06444
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.7119                0.2654          0.4601
# 1             0.2416                0.1860          0.2750
# 2             0.4504                0.2430          0.3613
# 3             0.6869                0.2575          0.6638
# 4             0.4000                0.1625          0.2364
# ..               ...                   ...             ...
# 564           0.4107                0.2216          0.2060
# 565           0.3215                0.1628          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                0.2650          0.4087
# 568           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 564                  0.07115
# 565                  0.06637
# 566                  0.07820
# 567                  0.12400
# 568                  0.07039
#
# [569 rows x 30 columns]

# %%
#normailze --- convert them to values between 0 to 1

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
scaler.fit(X)
# Out:
# MinMaxScaler()

# %%
X=scaler.transform(X)

# %%
X
# Out:
# array([[0.52103744, 0.0226581 , 0.54598853, ..., 0.91202749, 0.59846245,
#         0.41886396],
#        [0.64314449, 0.27257355, 0.61578329, ..., 0.63917526, 0.23358959,
#         0.22287813],
#        [0.60149557, 0.3902604 , 0.59574321, ..., 0.83505155, 0.40370589,
#         0.21343303],
#        ...,
#        [0.45525108, 0.62123774, 0.44578813, ..., 0.48728522, 0.12872068,
#         0.1519087 ],
#        [0.64456434, 0.66351031, 0.66553797, ..., 0.91065292, 0.49714173,
#         0.45231536],
#        [0.03686876, 0.50152181, 0.02853984, ..., 0.        , 0.25744136,
#         0.10068215]])

# %%
#split the dat

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=42)

# %%
x_train.shape
# Out:
# (426, 30)

# %%
x_test.shape
# Out:
# (143, 30)

# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Dropout

# %%
model=Sequential()

# %%
model.add(Dense(128, input_dim=30, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64,activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.compile(loss = 'binary_crossentropy', optimizer = 'adam' , metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               3968
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 1)                 65
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 12,289
# Trainable params: 12,289
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train,y_train,verbose = 1,epochs = 100, batch_size = 64,validation_data = (x_test,y_test))
# Out:
# Epoch 1/100
# 7/7 [==============================] - 4s 28ms/step - loss: 0.6870 - accuracy: 0.5094 - val_loss: 0.6510 - val_accuracy: 0.8881
# Epoch 2/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6613 - accuracy: 0.6080 - val_loss: 0.6138 - val_accuracy: 0.9021
# Epoch 3/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6424 - accuracy: 0.6972 - val_loss: 0.5727 - val_accuracy: 0.9161
# Epoch 4/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.
100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0723 - accuracy: 0.9765 - val_loss: 0.0515 - val_accuracy: 0.9860
# Epoch 70/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0601 - accuracy: 0.9836 - val_loss: 0.0512 - val_accuracy: 0.9790
# Epoch 71/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0647 - accuracy: 0.9789 - val_loss: 0.0493 - val_accuracy: 0.9790
# Epoch 72/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0754 - accuracy: 0.9695 - val_loss: 0.0547 - val_accuracy: 0.9790
# Epoch 73/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0575 - accuracy: 0.9812 - val_loss: 0.0483 - val_accuracy: 0.9860
# Epoch 74/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0746 - accuracy: 0.9695 - val_loss: 0.0471 - val_accuracy: 0.9860
# Epoch 75/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0670 - accuracy: 0.9765 - val_loss: 0.0548 - val_accuracy: 0.9790
# Epoch 76/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0596 - accuracy: 0.9836 - val_loss: 0.0471 - val_accuracy: 0.9860
# Epoch 77/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0687 - accuracy: 0.9789 - val_loss: 0.0493 - val_accuracy: 0.9860
# Epoch 78/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0623 - accuracy: 0.9765 - val_loss: 0.0501 - val_accuracy: 0.9860
# Epoch 79/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0651 - accuracy: 0.9765 - val_loss: 0.0477 - val_accuracy: 0.9790
# Epoch 80/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0674 - accuracy: 0.9765 - val_loss: 0.0515 - val_accuracy: 0.9860
# Epoch 81/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0561 - accuracy: 0.9859 - val_loss: 0.0488 - val_accuracy: 0.9860
# Epoch 82/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0703 - accuracy: 0.9765 - val_loss: 0.0496 - val_accuracy: 0.9860
# Epoch 83/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0571 - accuracy: 0.9812 - val_loss: 0.0488 - val_accuracy: 0.9860
# Epoch 84/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0611 - accuracy: 0.9836 - val_loss: 0.0509 - val_accuracy: 0.9860
# Epoch 85/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0584 - accuracy: 0.9883 - val_loss: 0.0509 - val_accuracy: 0.9860
# Epoch 86/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0634 - accuracy: 0.9812 - val_loss: 0.0489 - val_accuracy: 0.9790
# Epoch 87/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0620 - accuracy: 0.9789 - val_loss: 0.0494 - val_accuracy: 0.9790
# Epoch 88/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0655 - accuracy: 0.9789 - val_loss: 0.0517 - val_accuracy: 0.9860
# Epoch 89/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0656 - accuracy: 0.9789 - val_loss: 0.0516 - val_accuracy: 0.9860
# Epoch 90/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0642 - accuracy: 0.9765 - val_loss: 0.0491 - val_accuracy: 0.9860
# Epoch 91/100
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0548 - accuracy: 0.9859 - val_loss: 0.0490 - val_accuracy: 0.9790
# Epoch 92/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0554 - accuracy: 0.9859 - val_loss: 0.0529 - val_accuracy: 0.9860
# Epoch 93/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0592 - accuracy: 0.9836 - val_loss: 0.0536 - val_accuracy: 0.9860
# Epoch 94/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0614 - accuracy: 0.9789 - val_loss: 0.0544 - val_accuracy: 0.9790
# Epoch 95/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0541 - accuracy: 0.9765 - val_loss: 0.0508 - val_accuracy: 0.9860
# Epoch 96/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0616 - accuracy: 0.9765 - val_loss: 0.0522 - val_accuracy: 0.9790
# Epoch 97/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0491 - accuracy: 0.9859 - val_loss: 0.0532 - val_accuracy: 0.9790
# Epoch 98/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0397 - accuracy: 0.9906 - val_loss: 0.0514 - val_accuracy: 0.9790
# Epoch 99/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0504 - accuracy: 0.9859 - val_loss: 0.0527 - val_accuracy: 0.9790
# Epoch 100/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0521 - accuracy: 0.9812 - val_loss: 0.0532 - val_accuracy: 0.9790

# %%
y_pred = model.predict(x_test)
y_pred = (y_pred > 0.5)

# Making the Confusion Matrix:
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)

sns.heatmap(cm, annot = True)
# Out:
# 5/5 [==============================] - 0s 1ms/step
# <AxesSubplot: >
